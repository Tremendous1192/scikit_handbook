# %%
# ライブラリのインポート
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from mlxtend.plotting import plot_decision_regions

# %%
# XORのデータを作成する(x=正、y=正)=0,(x=正、y=負)=1
X_xor = np.array([[1.6,-0.6],[0.9,-2.4],[-0.3,-1.0]])
y_xor = np.array([1,1,0])                 

# 訓練データにセット
X_train, y_train = X_xor, y_xor

# SVCのモデルを作成
model = SVC(kernel='rbf', gamma=1.0 , C=100, random_state=0)
#model = SVC(kernel='linear', gamma=1.0 , C=100, random_state=0)

# モデルの訓練
model.fit(X_train, y_train)

# 訓練データのプロット
plt.figure(figsize=(8,4)) #プロットのサイズ指定
plot_decision_regions(X_train, y_train, model)
# Out:
# <Axes: >

# %%
# サポートベクトルのパラメータ
print(model.intercept_)
print(model.dual_coef_)
# Out:
# [0.33523906]
# [[-1.37376699  0.67914397  0.69462303]]

# %%
model.support_vectors_ # サポートベクトルの位置
# Out:
# array([[-0.3, -1. ],
#        [ 1.6, -0.6],
#        [ 0.9, -2.4]])

# %%
model.n_support_ # 各クラスのサポートベクトルの数
# Out:
# array([1, 2])
